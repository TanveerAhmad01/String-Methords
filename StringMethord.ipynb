# %%
# in this file we can learn about string methord
# as we can see that we have a lot of string  methords 
# first we have a varioble that we want to use 
# for exapmle i have a var
a = "tanveer is a Bad Boy"
# Now we can perform string methods on var(a)
# Some string methods are:
# a.upper() - Returns the string with all uppercase characters: "TANVEER IS A BAD BOY"
# a.lower() - Returns the string with all lowercase characters: "tanveer is a bad boy"
# a.title() - Returns a string where the first character of every word is uppercase: "Tanveer Is A Bad Boy"
# a.capitalize() - Makes the first character in the string uppercase: "Tanveer is a bad boy"
# a.strip() - Removes extra spaces at the beginning and end of the string: "tanveer is a Bad Boy"
# a.lstrip() - Removes spaces and characters specified in the parameter from the left side of the string: "is a Bad Boy"
# a.rstrip() - Removes spaces and characters specified in the parameter from the right side of the string:
#  "tanveer is a Bad Boy"

# a.replace("Bad", "Good") - Replaces the word "Bad" with "Good" in the string: "tanveer is a Good Boy"
# a.split() - Splits the string into a list of words: ['tanveer', 'is', 'a', 'Bad', 'Boy']
# a.center(12) - Centers the string within a field of 12 characters, padding with spaces: "tanveer is a Bad Boy"
# a.count("a") - Counts the number of occurrences of the character 'a' in the string: 4
# a.endswith("pasha") - Returns True or False, indicating whether the string ends with "pasha": False
# a.find("is") - Finds the index of the first occurrence of the word "is" in the string: 8
# a.isalpha() - Returns True if the string consists of alphabetic characters (A to Z, a to z), otherwise returns False
# a.islower() - Returns True if all characters in the string are lowercase, otherwise returns False: False
# now explain one by one

# number.isdecimal() - Returns True if the input string contains all decimal (int) characters, else it returns False.
# Example: "12345".isdecimal() returns True

# a.center(12) - Centers the string within a field of 12 characters, padding with spaces.
# Example: "tanveer is a Bad Boy".center(12) returns "tanveer is a Bad Boy"

# number.isdigit() - Returns True if the input string contains all digit (int) characters, else it returns False.
# Example: "12345".isdigit() returns True

# a.casefold() - Returns a string where all the characters are lower case.
# Example: "Tanveer Is A Bad Boy".casefold() returns "tanveer is a bad boy"

# a.index("t") - Returns the index number where "t" is first found in the string (returns 0 because "t" is at index 0).
# Example: "tanveer is a Bad Boy".index("t") returns 0


number = "12.342"
print(number.isdecimal())
print(a.upper())
# The upper() method returns the string in upper case
# output: "TANVEER IS A BAD BOY"

print(a.lower())
# The lower() method returns the string in lower case:
# output: "tanveer is a bad boy"

print(a.capitalize())
# The capitalize() method returns the string in capitalize case: like first word of sentence is upper
# for exapmle: "Tanveer is a bad boy"

b="     i am tanveer      "
print(b.strip())
# b.strip() this methord remove the sapce form string
# output is "i am tanveer"


print(a.lstrip())
# The lstrip() method returns the string and remove the word in left side here you can see the output of lstrip()
# output:"TANVEER IS A BAD BOY"
# now we can pass a parameter in lstrip we remove specaial word like that
print(a.lstrip("tanveer"))
# this methord remove left word that i pass in parameter
# output: "is a Bad Boy"

print(a.rstrip())
# The rstrip() method returns the string and remove the word in right side here you can see the output of rstrip()
# output:"TANVEER IS A BAD BOY"
# now we can pass a parameter in rstrip we remove specaial word like that
print(a.rstrip("Boy"))
# now the output is just like that "tanveer is a Bad"

# print(a.replace())
# The replace() method returns the string and replace the world that we like to remove 
# in this methord we can gave two parameter first paramater is that i have in my variable and second paramater that we can replace
# for example
# i have tanveer word in my var
print(a.replace("tanveer","pasha"))
# now tanveer replace by pasha
# and the oupput is "pasha is a Bad Boy"

print(a.split())
# is methord use to  change string into list
# i have my var can the output is just like that "tanveer is a Bad Boy" 
# this split() change into list like that ['tanveer', 'is', 'a', 'Bad', 'Boy']

print(len(a))
print(a.center(24))
print(len(a.center(50)))

# yah mthord hamri string ko center kar data haa.if i written 12 in paramter this can gave 12 space in first in string and 
# increase the len() of String
# for exp i have 10 len() of any string if i use this (a.center(12)) it can increase the length of sting now len is 12+10=22

b="pasha!! pasha  i am pasha"
b.count("pasha")
# this methord is used to count any word and single charcter from str 
# return 3
b.count("a")  #return 7  word in b var

b="pasha!! pasha  i am pasha"
print(b.endswith("pasha")) # retrun true
# endswith is used to check the end of our string,in paramater if we write the correvt word the return ture
print(b.endswith("am")) # retrun false
# beacuse our string not end with "am"

print(b.find("pasha")) # return 0
# that use to find any word in index 
# is because "pasha" is on 0 index that way return 0

print(b.find("rrwwqe")) # return -1
# becasue this word not exsit in var b  and return -1
# Out:
# False
# TANVEER IS A BAD BOY
# tanveer is a bad boy
# Tanveer is a bad boy
# i am tanveer
# tanveer is a Bad Boy
#  is a Bad Boy
# tanveer is a Bad Boy
# tanveer is a Bad
# pasha is a Bad Boy
# ['tanveer', 'is', 'a', 'Bad', 'Boy']
# 20
#   tanveer is a Bad Boy
# 50
# True
# False
# 0
# -1

# %%
statment = "My Name Is Ali"
data = "Hello World"
print(data.title())
print(statment.title())
print(data.istitle())
print(statment.istitle())
# Out:
# Hello World
# My Name Is Ali
# True
# True

# %%
# Assignment
#
number = "2132"
print(number.isdecimal())
txt= "i am pasha"
print(txt.center(78))

digit= "sad"
print(digit.index("d"))
# Out:
# True
#                                   i am pasha
# 2
